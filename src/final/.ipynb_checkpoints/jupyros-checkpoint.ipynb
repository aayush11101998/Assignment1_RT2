# %% [markdown]
# #                                      UI for RT_1 Assignment3

# %%
import jupyros as jr
from jupyros.ros1 import ros3d
import rospy
from ipywidgets import widgets
from ipywidgets import Button, Layout, ButtonStyle, GridBox, VBox, HBox, interact, interactive, fixed, interact_manual
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from std_srvs.srv import *
import os
import actionlib
from move_base_msgs.msg import MoveBaseAction, MoveBaseGoal
import time
import math
from sensor_msgs.msg import LaserScan
from geometry_msgs.msg import Twist, Point
from nav_msgs.msg import Odometry
from tf import transformations
from time import sleep
from __future__ import print_function
import threading
import roslib; roslib.load_manifest('teleop_twist_keyboard')
import sys, select, termios, tty

# %% [markdown]
# ##  Buttons to define robot state.

# %%
rospy.init_node('Jupyter_node')
pubv = rospy.Publisher('/cmd_vel', Twist, queue_size= 1)

def key(m1):
    rospy.set_param('robot_state', 'en_keys')
    print("keys enabled")
def obsavo(m2):
    rospy.set_param('robot_state', 'en_oa')
    print("obstacle avoidance enabled")
def mb(m3):
    rospy.set_param('robot_state', 'en_mb')
    print("movebase enabled")

# %%
en_keys = Button(
    description = "enable_usr_keys",
    layout=Layout(width='auto', align="center", grid_area='key'),
    style = ButtonStyle(button_color = 'lightblue')
)


en_oa = Button(
    description = "enable_OA assistance",
    layout=Layout(width='auto', align="center", grid_area='obsavo'),
    style = ButtonStyle(button_color = 'pink')
) 


en_movebase = Button(
    description = "enjoy self_driving",
    layout=Layout(width='auto', align="center", grid_area='mb'),
    style = ButtonStyle(button_color = 'lightgreen')
)

# %%
en_keys.on_click(key)
en_oa.on_click(obsavo)
en_movebase.on_click(mb)

Box = HBox([en_keys, en_oa, en_movebase])

display(Box)
# Out:
# HBox(children=(Button(description='enable_usr_keys', layout=Layout(grid_area='key', width='auto'), style=Butto…

# %% [markdown]
# ## Robot state 'en_movebase'

# %%
gr = 0
gnr = 0
def movebase(x, y):
    global a
    global b
    global gr
    global gnr
    global position
    twist = Twist()
    client = actionlib.SimpleActionClient('move_base',MoveBaseAction)
    position = rospy.wait_for_message("/odom", Odometry)
    goal = MoveBaseGoal()
    xr = position.twist.twist.linear.x
    yr = position.twist.twist.linear.y
    print('position of the robot:', xr, yr)
    goal.target_pose.header.frame_id = "map"
    goal.target_pose.header.stamp = rospy.Time.now()
    
    print("choose goal using sliders:")

    goal.target_pose.pose.position.x = x
    
    goal.target_pose.pose.position.y = y
    goal.target_pose.pose.orientation.w = 1.0
    
    client.wait_for_server()
    
    client.send_goal(goal)
    
    dist = ((x-xr)**2 + (y-yr)**2)**0.5
    if dist<0.5:
        gr += 1
    else:
        gnr += 1
    print("wait for vehicle to reach the goal")
    result = client.wait_for_result(timeout = rospy.Duration(30))

a = widgets.IntSlider(min = -20, max = 20, step = 1, value = 0, description = "x")
b = widgets.IntSlider(min = -20, max = 20, step = 1, value = 0, description = "y")
    
interact(movebase, x=a, y=b); 


#def newgoal(N):
#    print ("choose new goal:")
#    movebase(x, y)
    
def cancelgoal(C):
    global gnr
    vel = Twist()
    print("goal cancelled")
    vel.linear.x = 0
    vel.angular.z = 0
    pubv.publish(vel)
    gnr += 1

CG = Button(description='Cancel Goal',
                        layout=Layout(width='auto', grid_area='C'),
                        style=ButtonStyle(button_color='salmon'))
#NG = Button(description='New Goal',
                       # layout=Layout(width='auto', grid_area='N'),
                       # style=ButtonStyle(button_color='lightgreen'))
box = HBox([CG])
display(a, b, box)

#NG.on_click(newgoal)
CG.on_click(cancelgoal)
# Out:
# interactive(children=(IntSlider(value=0, description='x', max=20, min=-20), IntSlider(value=0, description='y'…
# IntSlider(value=0, description='x', max=20, min=-20)
# IntSlider(value=0, description='y', max=20, min=-20)
# HBox(children=(Button(description='Cancel Goal', layout=Layout(grid_area='C', width='auto'), style=ButtonStyle…

# %% [markdown]
# ## Map

# %%
view = ros3d.Viewer()
rc = ros3d.ROSConnection(url = "ws://localhost:9090")
tf_client= ros3d.TFClient(ros = rc, fixed_frame = 'map')
laser_view = ros3d.LaserScan(topic = "/scan", ros = rc, tf_client = tf_client)
map_view = ros3d.OccupancyGrid(topic = "/map", ros = rc, tf_client = tf_client)
path = ros3d.Path(topic = "/move_base/NavfnROS/plan", ros = rc, tf_client = tf_client)
urdf = ros3d.URDFModel(ros = rc, tf_client = tf_client, path = os.environ.get('JUPYROS_ASSETS_URL', 'http://localhost:3000')) 
grid = ros3d.GridModel()
view.objects = [grid, laser_view, map_view, path, urdf]

view
# Out:
# Viewer(objects=[GridModel(), LaserScan(ros=ROSConnection(url='ws://localhost:9090'), tf_client=TFClient(fixed_…

# %% [markdown]
# ## Robot State 'en_keys'

# %%
F = Button(description = 'Go forward',
           layout = Layout(width = 'auto', grid_area = 'F'),
           style = ButtonStyle(button_color = 'white'))
B= Button(description = 'Go backward',
          layout = Layout(width = 'auto', grid_area = 'B'),
          style = ButtonStyle(button_color = 'white'))
L= Button(description = 'Go left',
          layout = Layout(width = 'auto', grid_area = 'L'),
          style = ButtonStyle(button_color = 'white'))
R= Button(description = 'Go right',
          layout = Layout(width = 'auto', grid_area = 'R'),
          style = ButtonStyle(button_color = 'white'))
FL= Button(description = 'Go Straight left',
           layout = Layout(width = 'auto', grid_area = 'FL'),
           style = ButtonStyle(button_color = 'white'))
FR= Button(description = 'Go straight right',
           layout = Layout(width = 'auto', grid_area = 'FR'),
           style = ButtonStyle(button_color = 'white'))
BL=Button(description = 'Go Back left',
          layout = Layout(width = 'auto', grid_area = 'BL'),
          style = ButtonStyle(button_color = 'white'))
BR=Button(description = 'Go back right',
          layout = Layout(width = 'auto', grid_area = 'BR'),
          style = ButtonStyle(button_color = 'white'))
S= Button(description = 'Stop',
          layout = Layout(width = 'auto', grid_area = 'S'),
          style = ButtonStyle(button_color = 'red'))
IS = Button(description = 'Increase speed',
            layout = Layout(width = 'auto', grid_area = 'IS'),
            style = ButtonStyle(button_color = 'green'))
RS = Button(description = 'Reset speed',
            layout = Layout(width = 'auto', grid_area = 'RS'),
            style = ButtonStyle(button_color = 'yellow'))

speed = 0.5
turn = 0.5
def GoForward(b):
    vel = Twist()
    global speed
    vel.linear.x = 1.0*speed
    vel.angular.z = 0
    pubv.publish(vel)
    
def GoBackward(b):
    vel = Twist()
    global speed
    vel.linear.x = -1.0*speed
    vel.angular.z = 0
    pubv.publish(vel)
    
def GoLeft(b):
    vel = Twist()
    global turn
    vel.linear.x = 0
    vel.angular.z = 1.0*turn
    pubv.publish(vel)
    
def GoRight(b):
    vel = Twist()
    global turn
    vel.linear.x = 0
    vel.angular.z = -1.0*speed
    pubv.publish(vel)
    
def Gostraightleft(b):
    vel = Twist()
    global speed
    global turn
    vel.linear.x = 0.5*speed
    vel.angular.z = 1.0*turn
    pubv.publish(vel)
    
def Gostraightright(b):
    vel = Twist()
    global speed
    global turn
    vel.linear.x = 0.5*speed
    vel.angular.z = -1.0*turn
    pubv.publish(vel)
    
def Gobackleft(b):
    vel = Twist()
    global speed
    global turn
    vel.linear.x = -0.5*speed
    vel.angular.z = 1.0*turn
    pubv.publish(vel)
    
def Gobackright(b):
    vel = Twist()
    global speed
    global turn
    vel.linear.x = -0.5*speed
    vel.angular.z = -1.0*turn
    pubv.publish(vel)
    
def Increasevelocity(b):
    global speed
    global turn
    vel = Twist()
    speed = speed + 0.5
    turn = turn + 0.5
    print(speed)
    print(turn)
    print("press control buttons to enjoy high speed or increase more speed")
    pubv.publish(vel)
    
def Resetvelocity(b):
    global speed
    global turn
    speed = 0.5
    turn = 0.5
    vel = Twist()
    print(speed)
    print(turn)
    pubv.publish(vel)
    
    
def Stop(b):
    vel = Twist()
    speed = 0
    turn = 0
    pubv.publish(vel)
       
F.on_click(GoForward)
B.on_click(GoBackward)
L.on_click(GoLeft)
R.on_click(GoRight) 
FL.on_click(Gostraightleft)
FR.on_click(Gostraightright)
BL.on_click(Gobackleft)
BR.on_click(Gobackright)
IS.on_click(Increasevelocity)
RS.on_click(Resetvelocity)
S.on_click(Stop)

V1 = VBox([FL, L, BL])
V2 = VBox([F, S, B])
V3 = VBox([FR, R, BR])

Box1 = HBox([V1 ,V2 ,V3])

Box2 = VBox([IS, RS])

display(Box1)

display(Box2)
# Out:
# HBox(children=(VBox(children=(Button(description='Go Straight left', layout=Layout(grid_area='FL', width='auto…
# VBox(children=(Button(description='Increase speed', layout=Layout(grid_area='IS', width='auto'), style=ButtonS…

# %% [markdown]
# ## Robot State 'en_oa'

# %%
def LaserCallback(msg):
    
    if rospy.get_param('robot_state')=='en_oa':
        vel = Twist()
        global speed
        global turn
        minR = min(min(msg.ranges[0:240]), 10)
        minf = min(min(msg.ranges[241:480]), 10)
        minl = min(min(msg.ranges[481:720]), 10)
        
        if minf<1.0:
            vel.linear.x = 0
            vel.angular.z = 1.0*speed
            
        if minf<1.0 and minR<1.0:
            vel.linear.x = 0.5*speed
            vel.angular.z = 1.0*turn
            
        if minf<1.0 and minl<1.0:
            vel.linear.x = 0.5*speed
            vel.linear.z = -1.0*turn
            
        else:
            vel.linear.x = 1.0 * speed
            vel.angular.z = 0.5 * turn
            
        pubv.publish(vel)
        
V1 = VBox([FL, L, BL])
V2 = VBox([F, S, B])
V3 = VBox([FR, R, BR])

Box1 = HBox([V1 ,V2 ,V3])

Box2 = VBox([IS, RS])

display(Box1)
display(Box2)

rospy.sleep(1.0)
sub = rospy.Subscriber('/scan', LaserScan, LaserCallback)
# Out:
# HBox(children=(VBox(children=(Button(description='Go Straight left', layout=Layout(grid_area='FL', width='auto…
# VBox(children=(Button(description='Increase speed', layout=Layout(grid_area='IS', width='auto'), style=ButtonS…

# %% [markdown]
# ## DATA VISUALIZATION

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
from tf.transformations import quaternion_matrix

# %% [markdown]
# ## Robot odometery plot

# %%
class odomvisualiser():
    def __init__(self):
        self.fig2, self.ax2 = plt.subplots()
        self.ln1 = self.ax2.plot([], [], 'bx')
        self.x_data, self.y_data = [], []
    
    def plot(self):
        self.ax2.set_xlim(-20, 20)
        self.ax2.set_ylim(-20, 20)
        self.ax2.set_xlabel("X", fontweight="bold")
        self.ax2.set_ylabel("Y", fontweight="bold")
        
        return self.ln1
    
    def plot_callback(self, odom):
        self.x_data.append(odom.pose.pose.position.x)
        self.y_data.append(odom.pose.pose.position.y)
        
    def update_plot(self, frame):
        self.ln1.set_data(self.x_data, self.y_data)
        
        return self.ln1

    
vis0 = odomvisualiser() 
sub0 = rospy.Subscriber('/odom', Odometry, vis0.plot_callback)
ani0 = FuncAnimation(vis0.fig2, vis0.update_plot, init_func = vis0.plot)
# Out:
# [ERROR] [1677596031.840771, 1785.246000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.846719, 1785.250000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.847943, 1785.254000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
# [ERROR] [1677596031.849639, 1785.256000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.851294, 1785.258000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
# <img src="data:image/png;base64,..." width="640">
# [ERROR] [1677596031.854859, 1785.259000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.856599, 1785.263000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.869426, 1785.274000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.870741, 1785.277000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596031.872046, 1785.279000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'

# %% [markdown]
# ## LaserScan plot

# %%
class laservisualiser():
    def __init__(self):
        self.fig3, self.ax3 = plt.subplots()
        self.ln2 = self.ax3.plot([], [], 'g-')
        self.intensity, self.theta = [], []
        
    def laser(self):
        self.ax3.set_thetalim(-np.pi/2, np.pi/2)
        self.ax3.rmax(17)
        return self.ln2
    
    def laser_callback(self, msg):
        for i in plt.gca().lines + plt.gca().collections:
            i.remove()
            
        self.intensity = msg.ranges
        self.theta = np.arange(msg.angle_min, msg.angle_max + msg.angle_increment, msg.angle_increment)
        
        self.ln2 = self.ax3.plot(self.theta, self.intensity, 'g-')
        
        return self.ln2
    
    def update_laser(self, frame):
        return self.ln2
    
visL = laservisualiser()
subL = rospy.Subscriber('/scan', LaserScan, visL.laser_callback)
aniL = FuncAnimation(visL.fig3, visL.update_laser, init_func = visL.laser)
# Out:
# [ERROR] [1677596037.264690, 1790.667000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.270451, 1790.668000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.272614, 1790.674000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
# <img src="data:image/png;base64,..." width="640">
# [ERROR] [1677596037.285400, 1790.678000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.288033, 1790.690000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.288921, 1790.691000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.289789, 1790.692000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.290677, 1790.692000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.291610, 1790.693000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596037.292519, 1790.694000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'

# %% [markdown]
# ## Pie chart for goal reached and goal not reached

# %%
# a pie chart to visualize the number of goals reached and not reached

# %matplotlib widget
class targetvisualiser():
    def __init__(self):
        self.fig1, self.ax = plt.subplots()
    
    def pie(self):
        return self.ln
    
    def pie_callback(self, msg):
        global gr
        global gnr
        sizes = [gr, gnr]
        colors = ['green', 'blue']
        patches, texts = self.ax.pie(sizes, colors = colors, startangle = 90)
        labels = ['Reached: ' gr , 'Not reached: ' gnr]
        
        self.ax.pie(sizes, colors = colors, autopct = '%1.1f%%',shadow = False, startangle = 90)
        self.ax.legend(patches, labels, loc = "best")
        
    def update_pie(self, frame):
        return self.ln
    
visP = targetvisualiser()
subP = rospy.Subscriber('/clock', Clock, visP.pie_callback)
aniP = FuncAnimation(visP.fig1, visP.update_pie, init_func = visP.pie)
# Out:
# [ERROR] [1677596058.648883, 1812.031000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.649729, 1812.032000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.650467, 1812.033000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.651236, 1812.033000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.651827, 1812.034000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.652423, 1812.035000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.652996, 1812.035000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.653603, 1812.036000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.654197, 1812.036000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.654773, 1812.037000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.655371, 1812.038000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.655944, 1812.038000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.656759, 1812.039000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.657427, 1812.040000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.657944, 1812.040000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.658532, 1812.041000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.659197, 1812.041000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.659863, 1812.042000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.660521, 1812.043000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.661139, 1812.043000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.661789, 1812.044000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.678513, 1812.060000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#   Cell In[15], line 17
#     labels = ['Reached: ' gr , 'Not reached: ' gnr]
#                           ^
# SyntaxError: invalid syntax
# [ERROR] [1677596058.683779, 1812.066000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.685424, 1812.067000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.686539, 1812.069000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.688203, 1812.070000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.689144, 1812.071000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.689830, 1812.072000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.690535, 1812.073000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.691163, 1812.073000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.691793, 1812.074000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.692478, 1812.075000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.693054, 1812.075000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.693662, 1812.076000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.694211, 1812.076000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.694888, 1812.077000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.695466, 1812.078000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.696491, 1812.079000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.697481, 1812.080000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.698574, 1812.081000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.699583, 1812.082000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.700354, 1812.082000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.701015, 1812.083000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.701635, 1812.084000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.702181, 1812.084000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.702850, 1812.085000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.703539, 1812.086000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.704136, 1812.086000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.704760, 1812.087000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.705377, 1812.088000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.706031, 1812.088000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.706670, 1812.089000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.707263, 1812.089000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.707815, 1812.090000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.708437, 1812.091000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.709116, 1812.091000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.710081, 1812.092000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.710800, 1812.093000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.711549, 1812.094000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
#
# [ERROR] [1677596058.712183, 1812.094000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
# [ERROR] [1677596058.714381, 1812.095000]: bad callback: <bound method odomvisualiser.plot_callback of <__main__.odomvisualiser object at 0x7fac65e7ab50>>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_10106/436978260.py", line 16, in plot_callback
#     self.x_data.append(position.twist.twist.position.x)
# AttributeError: 'Twist' object has no attribute 'position'
